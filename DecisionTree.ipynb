# %%
import pandas as pd
import os
import matplotlib
os.chdir('/Users/s4b1e/Desktop/Work/Code/Python/MLM')
import sklearn
from sklearn.tree import DecisionTreeClassifier


df = pd.read_csv('music.csv')
z = df.drop(columns=['genre'])
y= df['genre']

model = DecisionTreeClassifier()
z = model.fit(z.values,y.values)
predictions = model.predict([[30,1],[62,0]])
predictions
# Out:
# array(['Jazz', 'Classical'], dtype=object)

# %%
sklearn.tree.plot_tree(z)
# Out:
# [Text(0.625, 0.875, 'x[0] <= 30.5\ngini = 0.778\nsamples = 18\nvalue = [3, 6, 3, 3, 3]'),
#  Text(0.5, 0.625, 'x[1] <= 0.5\ngini = 0.75\nsamples = 12\nvalue = [3, 0, 3, 3, 3]'),
#  Text(0.5625, 0.75, 'True  '),
#  Text(0.25, 0.375, 'x[0] <= 25.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 3, 0, 0]'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.375, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]'),
#  Text(0.75, 0.375, 'x[0] <= 25.5\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 3, 3]'),
#  Text(0.625, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.75, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0, 0]'),
#  Text(0.6875, 0.75, '  False')]

# %%
df
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical
